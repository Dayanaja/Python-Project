# %% [markdown]
# # 1. Data Understanding

# %% [markdown]
# # Import Requried libraries

# %%
import pandas as pd
import numpy as np

#Data visualization
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
df_lap=pd.read_csv(r"C:\Users\Admin\Downloads\Reinforcement Project - Python-20250403T050205Z-001\Reinforcement Project - Python\Laptop Dataset\laptopData.csv")
df_lap
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook   65.4
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df_laptop = df_lap.copy()
df_laptop
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook   65.4
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
# First 5 records of the dataset
df_laptop.head()
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0         0.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1         1.0   Apple  Ultrabook   13.3                            1440x900
# 2         2.0      HP   Notebook   15.6                   Full HD 1920x1080
# 3         3.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4         4.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df_laptop.tail()
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook   65.4
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# ...

# %% [markdown]
# # Shape of the dataset (rows, columns)

# %%
df_laptop.shape
# Out:
# (1303, 12)

# %% [markdown]
# # Basic information of the dataset

# %%
df_laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1273 non-null   float64
#  1   Company           1273 non-null   object
#  2   TypeName          1253 non-null   object
#  3   Inches            1220 non-null   object
#  4   ScreenResolution  1273 non-null   object
#  5   Cpu               1273 non-null   object
#  6   Ram               1259 non-null   object
#  7   Memory            1273 non-null   object
#  8   Gpu               1273 non-null   object
#  9   OpSys             1273 non-null   object
#  10  Weight            1259 non-null   object
#  11  Price             1273 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %% [markdown]
# # Descriptive Statistics

# %%
df_laptop.describe()
# Out:
#         Unnamed: 0          Price
# count  1273.000000    1273.000000
# mean    652.674784   59955.814073
# std     376.493027   37332.251005
# min       0.000000    9270.720000
# 25%     327.000000   31914.720000
# 50%     652.000000   52161.120000
# 75%     980.000000   79333.387200
# max    1302.000000  324954.720000

# %% [markdown]
# # Variables of the dataset

# %%
set(df_laptop)
# Out:
# {'Company',
#  'Cpu',
#  'Gpu',
#  'Inches',
#  'Memory',
#  'OpSys',
#  'Price',
#  'Ram',
#  'ScreenResolution',
#  'TypeName',
#  'Unnamed: 0',
#  'Weight'}

# %% [markdown]
# # Basic Cleanup of the large number of missing values

# %%
# Number of missing values in each column

df_laptop.isnull().sum()
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            50
# Inches              83
# ScreenResolution    30
# Cpu                 30
# Ram                 44
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              44
# Price               30
# dtype: int64

# %%
df_laptop.isnull().sum().sum()
# Out:
# 461

# %%
# Percentage of missing values in each column corresponding to total number of records

round(100*(df_laptop.isnull().sum()/len(df_laptop.index)), 2).sort_values(ascending=False)

# (889/39717)*100
# Out:
# Inches              6.37
# TypeName            3.84
# Ram                 3.38
# Weight              3.38
# Unnamed: 0          2.30
# Company             2.30
# ScreenResolution    2.30
# Cpu                 2.30
# Memory              2.30
# Gpu                 2.30
# OpSys               2.30
# Price               2.30
# dtype: float64

# %%
# Maximum number of missing values across the rows of the dataset

df_laptop.isnull().sum(axis=1).max()
# Out:
# 12

# %% [markdown]
# # 2.Data Cleaning

# %%
#unique values of each column in the dataframe(to determine the repetitive) 
df_laptop.apply(lambda x : x.unique())
# Out:
# Company             [Apple, HP, Acer, Asus, Dell, Lenovo, nan, Chu...
# TypeName            [Ultrabook, Notebook, nan, Gaming, 2 in 1 Conv...
# Inches              [13.3, 15.6, 15.4, 14.0, 12.0, nan, 17.3, 13.5...
# ScreenResolution    [IPS Panel Retina Display 2560x1600, 1440x900,...
# Cpu                 [Intel Core i5 2.3GHz, Intel Core i5 1.8GHz, I...
# Ram                            [8, 16, 4, 0, 2, 12, 64, 6, 32, 24, 1]
# Memory              [128GB SSD, 128GB Flash Storage, 256GB SSD, 51...
# Gpu                 [Intel Iris Plus Graphics 640, Intel HD Graphi...
# OpSys               [macOS, No OS, Windows 10, Mac OS X, nan, Linu...
# Weight              [1.37, 1.34, 1.86, 1.83, 2.1, 2.04, 1.3, 1.6, ...
# Price               [71378.6832, 47895.5232, 30636.0, 135195.336, ...
# dtype: object

# %%
if 'Unnamed:0' in df_laptop.columns:
    df_laptop.drop(columns=['Unnamed: 0'], inplace=True)
df_laptop
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible   14.0
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook   65.4
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
print(df_laptop.columns.tolist())
# Out:
# ['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price']

# %%
df_laptop=df_laptop.replace('?',np.nan)
df_laptop
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible   14.0
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook   65.4
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df_laptop.columns=df_laptop.columns.str.strip()
df_laptop
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible   14.0
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook   65.4
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
#Remove units and convert data to appropriate types
df_laptop.loc [:,'Ram'] = df_laptop['Ram'].astype(str).str.replace('GB', '', regex=False).astype(float)
df_laptop.loc[:,'Weight']=df_laptop['Weight'].astype(str).str.replace ('kg','',regex=False)
df_laptop.loc[:,'Weight']=pd.to_numeric(df_laptop['Weight'].astype(str).str.replace('kg','',regex=False),errors='coerce')
df_laptop.loc[:,'Inches']=pd.to_numeric(df_laptop['Inches'],errors='coerce')

df_laptop
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible   14.0
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook   65.4
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %% [markdown]
# # Types Conversion

# %%
# Convert 'Ram' to numeric
# Step 1: Extract digits from strings like '8GB', '16 GB'
df_laptop['Ram'] = df_laptop['Ram'].astype(str).str.extract(r'(\d+)')[0]

# Step 2: Convert to numeric (will convert invalid entries to NaN)
df_laptop['Ram'] = pd.to_numeric(df_laptop['Ram'], errors='coerce')

# Convert 'Weight' to numeric
# Step 1: Remove 'kg' or other text from the weight strings
df_laptop['Weight'] = df_laptop['Weight'].astype(str).str.replace('kg', '', regex=False).str.strip()

# Step 2: Convert to numeric
df_laptop['Weight'] = pd.to_numeric(df_laptop['Weight'], errors='coerce')

# %%
df_laptop.dtypes
# Out:
# Company              object
# TypeName             object
# Inches               object
# ScreenResolution     object
# Cpu                  object
# Ram                   int64
# Memory               object
# Gpu                  object
# OpSys                object
# Weight              float64
# Price               float64
# dtype: object

# %%
#Drop rows with more than 3 missing values
df_laptop=df_laptop[df_laptop.isnull().sum(axis=1)<=3]
df_laptop
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible   14.0
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook   65.4
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
# Maximum number of missing values across the rows of the dataset

df_laptop.isnull().sum(axis=1).max()
# Out:
# 1

# %% [markdown]
# # Handling the missing values

# %%
# Check missing values again
print(df_laptop.isnull().sum())
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# Gaming              0
# dtype: int64

# %%
# Use .loc to safely assign values on a slice
df_laptop.loc[:, 'TypeName'] = df_laptop['TypeName'].fillna(df_laptop['TypeName'].mode()[0])
df_laptop.loc[:, 'Inches'] = df_laptop['Inches'].fillna(df_laptop['Inches'].median()).infer_objects(copy=False)
df_laptop.loc[:, 'Ram'] = df_laptop['Ram'].fillna(df_laptop['Ram'].median()).infer_objects(copy=False)
df_laptop.loc[:, 'Memory'] = df_laptop['Memory'].fillna(df_laptop['Memory'].mode()[0])

df_laptop
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible   14.0
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook   65.4
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df_laptop = df_laptop.drop_duplicates()
df_laptop.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # To Detect the outliers

# %%
# Boxplot of 'Weight' to check for outliers
plt.figure(figsize=(8, 5))
sns.boxplot(x=df_laptop['Price'])
plt.title('Outliers in Price')
plt.show()

# %%
# Boxplot of 'Weight' to check for outliers
plt.figure(figsize=(8, 5))
sns.boxplot(x=df_laptop['Weight'])
plt.title('Outliers in Weight')
plt.show()

# %%
# Boxplot of 'Inches' to check for outliers
plt.figure(figsize=(8, 5))
sns.boxplot(x=df_laptop['Inches'])
plt.title('Outliers in Inches')
plt.show()

# %% [markdown]
# # Remove the outliers

# %%
# Step 1: Remove outliers
Q1 = df_laptop['Price'].quantile(0.25)
Q3 = df_laptop['Price'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Clean the dataset by filtering out the outliers
df_laptop_cleaned = df_laptop[(df_laptop['Price'] >= lower_bound) & (df_laptop['Price'] <= upper_bound)]

# Step 2: Visualize the comparison
plt.figure(figsize=(12, 6))

# Plot after removing outliers
plt.subplot(1, 2, 2)
sns.boxplot(x=df_laptop_cleaned['Price'])
plt.title('After Removing Outliers')

plt.tight_layout()
plt.show()

# %%
# Step 1: Remove outliers for 'Weight'
Q1 = df_laptop['Weight'].quantile(0.25)
Q3 = df_laptop['Weight'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Clean the dataset by filtering out the outliers based on 'Weight'
df_laptop_cleaned = df_laptop[(df_laptop['Weight'] >= lower_bound) & (df_laptop['Weight'] <= upper_bound)]

# Step 2: Visualize the comparison
plt.figure(figsize=(12, 6))

# Plot after removing outliers
plt.subplot(1, 2, 2)
sns.boxplot(x=df_laptop_cleaned['Weight'])
plt.title('After Removing Outliers')

plt.tight_layout()
plt.show()

# %%
# Step 1: Remove outliers for 'Inches'
Q1_inches = df_laptop['Inches'].quantile(0.25)
Q3_inches = df_laptop['Inches'].quantile(0.75)
IQR_inches = Q3_inches - Q1_inches

lower_bound_inches = Q1_inches - 1.5 * IQR_inches
upper_bound_inches = Q3_inches + 1.5 * IQR_inches

# Clean the dataset by filtering out the outliers based on 'Inches'
df_laptop_cleaned_inches = df_laptop[(df_laptop['Inches'] >= lower_bound_inches) & (df_laptop['Inches'] <= upper_bound_inches)]

# Step 2: Visualize the comparison for 'Inches'
plt.figure(figsize=(12, 6))

# Plot after removing outliers
plt.subplot(1, 2, 2)
sns.boxplot(x=df_laptop_cleaned_inches['Inches'])
plt.title('After Removing Outliers (Inches)')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Hypothesis Testing for avg price of laptops

# %%
from scipy.stats import ttest_1samp

# Assume we're testing if the mean price is ₹50,000
hypothesized_mean_price = 50000

# Perform a one-sample t-test
t_stat, p_val = ttest_1samp(df_laptop['Price'], hypothesized_mean_price)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")

if p_val < 0.05:
    print("Reject H₀: The mean price is significantly different from ₹50,000.")
else:
    print("Fail to Reject H₀: No significant difference from ₹50,000.")
# Out:
# T-statistic: 9.960377019834981
# P-value: 1.5449422654938793e-22
# Reject H₀: The mean price is significantly different from ₹50,000.

# %% [markdown]
# # Hypothesis Testing for RAM & Price

# %%
from scipy.stats import ttest_ind, ttest_1samp   # add ttest_ind here
import pandas as pd
import numpy as np

# Ensure RAM is numeric
df_laptop['Ram'] = pd.to_numeric(
    df_laptop['Ram'].astype(str).str.extract(r'(\d+)')[0],
    errors='coerce'
)

# Ensure Price is numeric
df_laptop['Price'] = pd.to_numeric(df_laptop['Price'], errors='coerce')

# Drop missing values
df_clean = df_laptop.dropna(subset=['Ram', 'Price'])

# Create two groups
group_low  = df_clean[df_clean['Ram'] <= 8]['Price']
group_high = df_clean[df_clean['Ram'] > 8]['Price']

# Perform two‑sample Welch’s t‑test
t_stat, p_val = ttest_ind(group_high, group_low, equal_var=False)

print(f"T‑statistic: {t_stat:.4f}")
print(f"P‑value:     {p_val:.4f}")

if p_val < 0.05:
    print("Reject H₀: Price differs significantly based on RAM size.")
else:
    print("Fail to Reject H₀: No significant price difference based on RAM.")
# Out:
# T‑statistic: 19.5599
# P‑value:     0.0000
# Reject H₀: Price differs significantly based on RAM size.

# %% [markdown]
# # Hypothesis Testing for chi-square on company and Typename

# %%
import pandas as pd
from scipy.stats import chi2_contingency
import seaborn as sns

contingency_table = pd.crosstab(df_laptop['Company'], df_laptop['TypeName'])

chi2, p, dof, expected = chi2_contingency(contingency_table)

print("Chi-square statistic:", chi2)
print("p-value:", p)
print("Degrees of freedom:", dof)

if p < 0.05:
    print("Reject the null hypothesis - variables are not independent")
else:
    print("Fail to reject the null hypothesis - variables are independent")
# Out:
# Chi-square statistic: 684.9704939303504
# p-value: 2.6284285021297643e-92
# Degrees of freedom: 90
# Reject the null hypothesis - variables are not independent

# %% [markdown]
# # Univariant Analysis

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df_laptop['Price'], kde=True, color='darkmagenta')
plt.title('Distribution of Laptop Prices')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Laptop Type Distribution

# %%
# Count the occurrences of each laptop type
type_name_counts = df_laptop['TypeName'].value_counts()

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(type_name_counts, labels=type_name_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Laptop Type Distribution')
plt.show()

# %% [markdown]
# # Laptop Weight

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df_laptop, x='Weight', kde=True, bins=30, color='darkmagenta')
# Center the title explicitly
plt.title('Distribution of Laptop Weight')
plt.show()

# %% [markdown]
# # Operating System

# %%
# 1. Frequency Distribution
os_counts = df_laptop['OpSys'].value_counts()

# 2. Proportions
os_proportions = df_laptop['OpSys'].value_counts(normalize=True)

# 3. Visual Representation (Bar Plot)
plt.figure(figsize=(8, 6))
os_counts.plot(kind='bar', color='darkmagenta')
plt.title('Distribution of Operating Systems in Laptop Dataset')
plt.xlabel('Operating System')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Laptop Screen Sizes

# %%
plt.figure(figsize=(8,5))
sns.histplot(df_laptop['Inches'], kde=True, bins=15, color='purple')
plt.title('Distribution of Laptop Screen Sizes')
plt.show()

# %% [markdown]
# # Number of Laptops by Company

# %%
Company_counts = df_laptop['Company'].value_counts().index
plt.figure(figsize=(10, 6))
sns.countplot(x='Company', hue='Company', data=df_laptop, palette='viridis', legend=False, order=Company_counts)
plt.title('Number of Laptops by Company')
plt.xlabel('Company')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Bivariant Analysis

# %% [markdown]
# # Price Vs RAM

# %%
df_laptop.loc[:,'Ram'] = df_laptop['Ram'].astype(str).str.replace('GB', '', regex=False).astype(float)

plt.figure(figsize=(8, 5))
sns.boxplot(x='Ram', y='Price', data=df_laptop)
plt.title('Price vs RAM')
plt.xlabel('RAM (GB)')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# # Price Vs CPU

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Compute median price per CPU and pick top 10
median_prices = (
    df_laptop
    .groupby('Cpu')['Price']
    .median()
    .sort_values(ascending=False)
)
top10_cpus = median_prices.head(10).index

# 2. Filter to just those top 10 and plot in that order
plt.figure(figsize=(10, 6))
sns.boxplot(
    x='Cpu',
    y='Price',
    data=df_laptop[df_laptop['Cpu'].isin(top10_cpus)],
    order=top10_cpus
)
plt.xticks(rotation=45, ha='right')
plt.title('Price vs CPU (Top 10 by Median Price)')
plt.xlabel('CPU Type')
plt.ylabel('Price')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Price Vs Gpu

# %%
# 1. Compute median price per CPU and pick top 10
median_prices = (
    df_laptop
    .groupby('Gpu')['Price']
    .median()
    .sort_values(ascending=False)
)
top10_cpus = median_prices.head(10).index

# 2. Filter to just those top 10 and plot in that order
plt.figure(figsize=(10, 6))
sns.boxplot(
    x='Gpu',
    y='Price',
    data=df_laptop[df_laptop['Gpu'].isin(top10_cpus)],
    order=top10_cpus
)
plt.xticks(rotation=45, ha='right')
plt.title('Price vs GPU (Top 10 by Median Price)')
plt.xlabel('GPU Type')
plt.ylabel('Price')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Screen Size Vs Weight

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Inches', y='Weight', data=df_laptop)
plt.title('Screen Size vs Weight')
plt.xlabel('Screen Size (Inches)')
plt.ylabel('Weight')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_laptop, x='TypeName', y='Weight')
plt.title('Laptop Weight by Type')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Price Distribution by Company

# %%
# Select only the first 10 unique companies for the x-axis
top_10_companies = df_laptop['Company'].unique()[:10]

# Filter the DataFrame to include only the top 10 companies
df_laptop_filtered = df_laptop[df_laptop['Company'].isin(top_10_companies)]

# Create the violin plot
plt.figure(figsize=(12, 6))
sns.violinplot(x='Company', y='Price', data=df_laptop_filtered, hue='Company', palette='viridis', legend=False)

# Customizing the plot
plt.title('Price Distribution by Company (Violin Plot)')
plt.xlabel('Company')
plt.ylabel('Price')
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# # Multivariant Analysis

# %%
# --- Correlation Matrix (Only Numeric Columns) ---
plt.figure(figsize=(12, 8))
sns.heatmap(df_laptop.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
# --- Pair Plot ---
sns.pairplot(df_laptop[['Price', 'Ram', 'Inches', 'Weight']], diag_kind='kde')
plt.show()
